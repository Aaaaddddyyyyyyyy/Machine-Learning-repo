# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaaaddddyyyyyyyy/Machine-Learning-repo/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification      # make classification to make classification datasets
X,y=make_classification(n_samples=100,n_informative=1,n_features=2,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=1,class_sep=10)

# %%
np.insert(X,0,1,axis=1)
# Out:
# array([[  1.        ,   0.31515939, -10.15316588],
#        [  1.        ,  -0.18656977,  -8.98053226],
#        [  1.        ,   0.81095167,  10.07711906],
#        [  1.        ,   0.98633519,   9.89043578],
#        [  1.        ,  -1.31228341, -10.23589018],
#        [  1.        ,  -1.37311732,  -9.80404287],
#        [  1.        ,  -0.22631424,   9.80349396],
#        [  1.        ,  -0.11044703,   9.95815825],
#        [  1.        ,   0.3380117 , -10.41995276],
#        [  1.        ,   0.68006984,  10.06867504],
#        [  1.        ,   0.36949272,   9.7466808 ],
#        [  1.        ,   0.68255141,  -8.71000147],
#        [  1.        ,   0.16938243, -10.65902848],
#        [  1.        ,  -1.14434139, -10.00777873],
#        [  1.        ,   0.50318481,  10.04986347],
#        [  1.        ,   1.96710175,  -9.2968988 ],
#        [  1.        ,  -1.09491185, -10.32440858],
#        [  1.        ,  -1.62743834,  10.14325363],
# ...

# %%
plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)

# %%
def perceptron(X,y):
  X= np.insert(X,0,1,axis=1)
  weights=np.ones(X.shape[1])
  lr=0.1

  for i in range(1000):             ### looop for 1000 times as outr epoch
    j=np.random.randint(0,100)
    y_hat=step(np.dot(X[j],weights))
    weights=weights + lr*(y[j]-y_hat)*X[j]

  return weights[0],weights[1:]

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %% [markdown]
# MAking a step function

# %%
def step(z):
  return 1 if z>0 else 0        ##   step function used to return output value of the model

# %%
intercept_,coef_=perceptron(X,y)

print('intercept :',intercept_)
print('coef :',coef_)
# Out:
# intercept : 1.0
# coef : [1. 1.]

# %%
m = -(coef_[0]/coef_[1])        # finding the values of slope and intercept using the formula m = -a/b , b= -c/b
b = -(intercept_/coef_[1])

# %%
x_input= np.linspace(-3,3,100)
y_input= m*x_input +b

# %%
plt.figure(figsize=(10,6))
plt.plot(x_input,y_input,color='red',linewidth=3)
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=-100)
plt.ylim(-3,2)
plt.show()

# %%
from sklearn.datasets import make_classification
import numpy as np
X,y=make_classification(n_samples=100,n_features=2,n_informative=1,n_redundant=0,n_classes=2,n_clusters_per_class=1,random_state=12,hypercube=False,class_sep=30)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.scatter(X[:,0],X[:,1],c=y,cmap='winter',s=100)
