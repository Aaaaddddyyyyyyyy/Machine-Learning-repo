# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaaaddddyyyyyyyy/Machine-Learning-repo/blob/main/Polynomial_features_in_lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as  plt

# %%
df= pd.read_csv('ushape.csv')

# %%
df.head()
# Out:
#    3.159499363321345566e-02  9.869877579082642072e-01  \
# 0                  2.115098                 -0.046244
# 1                  0.882490                 -0.075756
# 2                 -0.055144                 -0.037332
# 3                  0.829545                 -0.539321
# 4                  2.112857                  0.662084
#
#    0.000000000000000000e+00
# 0                       1.0
# 1                       0.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
X=df.iloc[:,0:-2].values
y=df.iloc[:,-1].values

# %%
plt.scatter(X,y,color='yellow')

# %%
## applying the logistic regression
from sklearn.linear_model import LogisticRegression
clf=LogisticRegression()

# %%
clf.fit(X,y)
# Out:
# LogisticRegression()

# %%
## decision boundary  of this model
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X,y.astype(int),clf,legend=True)
# Out:
# <Axes: >

# %%
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X)
accuracy = accuracy_score(y, y_pred)
accuracy
# Out:
# 0.6464646464646465

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3,include_bias=False)
X_trf=poly.fit_transform(X)

# %%
from sklearn.linear_model import LogisticRegression
clf1=LogisticRegression()
clf1.fit(X_trf,y_pred)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import accuracy_score
y_pred1=clf1.predict(X_trf)
accuracy=accuracy_score(y,y_pred1)
accuracy
# Out:
# 0.6464646464646465
