# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaaaddddyyyyyyyy/Machine-Learning-repo/blob/main/Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import load_diabetes
data= load_diabetes()

# %%
print(data.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
X=data.data
y=data.target                   ## extraction of input and output

# %%
from sklearn.model_selection import train_test_split                  ## train test split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=20,random_state=10)

# %%
from sklearn.linear_model import LinearRegression       # creatiung thwe object
L=LinearRegression()
L.fit(X_train,y_train)        ## training the model
# Out:
# LinearRegression()

# %%
y_pred=L.predict(X_test)      ## ppredicting on test dataset using the predict function

# %%
from sklearn.metrics import r2_score,mean_squared_error
                                                          #$# predicting ther mse and r2 score
print(r2_score(y_test,y_pred))
print(mean_squared_error(y_test,y_pred))
# Out:
# 0.5180909477777654
# 2258.923382066482

# %%
from sklearn.linear_model import Ridge        ## training using ridge model
R=Ridge(alpha=0.001)              ## alpha isna hyper paramtrer
R.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.001)

# %%
y_pred1=R.predict(X_test)       ## predicting the value of ridge usu9ing prediction functiuon

# %%
print("r2_score",r2_score(y_test,y_pred1))
print("mse",mean_squared_error(y_test,y_pred1))
# Out:
# r2_score 0.5193893850057072
# mse 2252.8370257284596

# %% [markdown]
# Ridge regression

# %%
from sklearn.datasets import  make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y=make_regression(n_samples=100,n_features=1, n_informative=1,n_targets=1, noise=10,random_state=34)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()             # makung thew class of linear regression model
lr.fit(X,y)                       ## traing the linear regressiojn moidel
print('coef ',lr.coef_)
print("Intercept",lr.intercept_)
# Out:
# coef  [2.74973618]
# Intercept 1.8677494015142004

# %%
from sklearn.linear_model import Ridge

r=Ridge(alpha=10)
r.fit(X,y)
print("coef of ridge",r.coef_)
print("intercept of  ridge",r.intercept_)
# Out:
# coef of ridge [2.44296886]
# intercept of  ridge 1.8894764903574168

# %% [markdown]
# Lasso regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

# %%
X,y=make_regression(n_samples=100,n_features=1,n_informative=1,n_targets=1,noise=20,random_state=30)    # 1d data as 1 input column(features), 1 output column(informative)
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
plt.scatter(X,y)

from sklearn.linear_model import LinearRegression

reg=LinearRegression()
reg.fit(X_train,y_train)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [20.58368395]
# 0.822965699091212

# %%
alpha=[0,15,10,30]
plt.figure(figsize=(12,6))
plt.scatter(X,y)

for i in alpha:
  L= Lasso(alpha=i)
  L.fit(X_train,y_train)
  plt.plot(X_test,L.predict(X_test),label='alpha={}'.format(i))
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:1389: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.526e+04, tolerance: 6.625e+00 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# ...
